# %%
#!pip install river

# %%
import itertools
import pandas as pd
from river.datasets import synth

# %%
df_raw = synth.Agrawal(classification_function=0, seed=42)

sliced = itertools.islice(df_raw, 10000)
data   = list(sliced)

X_list = [x for x, y in data]
y_list = [y for x, y in data]

pd.DataFrame(X_list)
# Out:
#              salary    commission  age  elevel  car  zipcode         hvalue  \
# 0     103125.483800      0.000000   21       2    8        3  319768.964263
# 1     135983.343802      0.000000   25       4   14        0  423837.775550
# 2      98262.434776      0.000000   55       1   18        6  144088.124408
# 3     133009.041703      0.000000   68       1   14        5  233361.402501
# 4      63757.290865  16955.938254   26       2   12        4  522851.309310
# ...             ...           ...  ...     ...  ...      ...            ...
# 9995   44733.737673  74966.006994   20       2    4        5  338997.765699
# 9996  101590.880321      0.000000   23       4    3        6  251495.448987
# 9997  109870.781688      0.000000   41       4   18        5  369296.489642
# 9998  103638.570994      0.000000   32       1    2        2  635054.201909
# 9999   55383.130682  58788.216491   60       4   11        0  963526.273251
#
#       hyears           loan
# ...

# %%
# Out:
#              salary    commission  age  elevel  car  zipcode         hvalue  \
# 0     103125.483800      0.000000   21       2    8        3  319768.964263
# 1     135983.343802      0.000000   25       4   14        0  423837.775550
# 2      98262.434776      0.000000   55       1   18        6  144088.124408
# 3     133009.041703      0.000000   68       1   14        5  233361.402501
# 4      63757.290865  16955.938254   26       2   12        4  522851.309310
# ...             ...           ...  ...     ...  ...      ...            ...
# 9995   44733.737673  74966.006994   20       2    4        5  338997.765699
# 9996  101590.880321      0.000000   23       4    3        6  251495.448987
# 9997  109870.781688      0.000000   41       4   18        5  369296.489642
# 9998  103638.570994      0.000000   32       1    2        2  635054.201909
# 9999   55383.130682  58788.216491   60       4   11        0  963526.273251
#
#       hyears           loan
# ...
